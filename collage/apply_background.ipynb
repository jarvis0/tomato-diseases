# %%
from PIL import Image
import os
import random
import shutil
from random import shuffle

# %%
def shuffle_backgrounds():
    backgrounds = sorted(os.listdir('./' + background_folder))
    shuffle(backgrounds)
    return backgrounds

# %%
alpha_folder = "../alpha_data"
folders = ['train', 'val', 'segmented_test']
augmented_folder = "../augmented_data"
classes = sorted(os.listdir(alpha_folder + '/' +folders[0]))
background_folder = 'backgrounds'
backgrounds = shuffle_backgrounds()   
print(backgrounds[10])

if os.path.exists(augmented_folder):
    shutil.rmtree(augmented_folder)
os.mkdir(augmented_folder)
# Out:
# background1568.png

# %%
def open_background(backgrounds, i):
        chosen_background = backgrounds[i]
        return Image.open(background_folder + '/' + chosen_background)

# %%
def apply_background(i, src, dest):
    for img in os.listdir(src):
        background = open_background(backgrounds, i % len(backgrounds))
        i = i+1
        image = Image.open(src + img)
        background.paste(image, (0,0), image)
        background = background.convert('RGB')
        background.save(dest + img, "PNG")
    return i
        

i = 0
for folder in folders:
    if os.path.exists(augmented_folder + '/' + folder):
        shutil.rmtree(augmented_folder + '/' + folder)
    os.mkdir(augmented_folder + '/' + folder)
    for clss in classes:
        if os.path.exists(augmented_folder+ '/' + folder + '/' + clss):
            shutil.rmtree(augmented_folder+ '/' + folder + '/' + clss)
        dest = augmented_folder+ '/' + folder + '/' + clss + '/'
        os.mkdir(dest)
        src = alpha_folder + '/' + folder + '/' + clss + '/'
        print(src)
        i = apply_background(i, src, dest)
# Out:
# ../alpha_data/train/Bacterial_spot/
# ../alpha_data/train/Early_blight/
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\PIL\ImageFile.py in _save(im, fp, tile, bufsize)
#     476     try:
# --> 477         fh = fp.fileno()
#     478         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-0494f514c104> in <module>()
#      22         src = alpha_folder + '/' + folder + '/' + clss + '/'
#      23         print(src)
# ---> 24         i = apply_background(i, src, dest)
#
# <ipython-input-15-0494f514c104> in apply_background(i, src, dest)
#       6         background.paste(image, (0,0), image)
#       7         background = background.convert('RGB')
# ----> 8         background.save(dest + img, "PNG")
#       9     return i
#      10
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    1933
#    1934         try:
# -> 1935             save_handler(self, fp, filename)
#    1936         finally:
#    1937             # do what we can to clean up
#
# ~\Anaconda3\lib\site-packages\PIL\PngImagePlugin.py in _save(im, fp, filename, chunk)
#     820
#     821     ImageFile._save(im, _idat(fp, chunk),
# --> 822                     [("zip", (0, 0)+im.size, 0, rawmode)])
#     823
#     824     chunk(fp, b"IEND", b"")
#
# ~\Anaconda3\lib\site-packages\PIL\ImageFile.py in _save(im, fp, tile, bufsize)
#     489             else:
#     490                 while True:
# --> 491                     l, s, d = e.encode(bufsize)
#     492                     fp.write(d)
#     493                     if s:
#
# KeyboardInterrupt:

# %%
# Out:
# ['background1664.png', 'background1786.png', 'background3450.png', 'background998.png', 'background1426.png', 'background4162.png', 'background3621.png', 'background719.png', 'background66.png', 'background1424.png', 'background1568.png', 'background4056.png', 'background3034.png', 'background2426.png', 'background1822.png', 'background3163.png', 'background3219.png', 'background2546.png', 'background3036.png', 'background3043.png', 'background1112.png', 'background3706.png', 'background394.png', 'background3898.png', 'background1336.png', 'background1338.png', 'background3602.png', 'background2459.png', 'background2043.png', 'background1500.png', 'background3050.png', 'background574.png', 'background1872.png', 'background268.png', 'background2828.png', 'background2606.png', 'background3728.png', 'background3092.png', 'background3590.png', 'background2598.png', 'background215.png', 'background1943.png', 'background276.png', 'background808.png', 'background241.png', 'background620.png', 'background3227.png', 'background2077.png', 'background3409.png', 'background2541.png', 'background2290.png', 'background3523.png', 'background1244.png', 'background2342.png', 'background1273.png', 'background133.png', 'background3579.png', 'background593.png', 'background1825.png', 'background214.png', 'background3194.png', 'background3295.png', 'background3646.png', 'background2446.png', 'background3531.png', 'background2066.png', 'background3360.png', 'background1594.png', 'background836.png', 'background2652.png', 'background3356.png', 'background592.png', 'background1088.png', 'background2297.png', 'background2238.png', 'background3154.png', 'background2767.png', 'background1283.png', 'background2215.png', 'background801.png', 'background1202.png', 'background319.png', 'background1591.png', 'background3153.png', 'background3231.png', 'background3920.png', 'background3553.png', 'background887.png', 'background35.png', 'background3193.png', 'background3130.png', 'background2208.png', 'background1806.png', 'background3815.png', 'background2508.png', 'background1310.png', 'background2529.png', 'background127.png', 'background1467.png', 'background3332.png', 'background4114.png', 'background2139.png', 'background1076.png', 'background1892.png', 'background3693.png', 'background324.png', 'background232.png', 'background2777.png', 'background3505.png', 'background563.png', 'background3626.png', 'background3635.png', 'background2445.png', 'background940.png', 'background2084.png', 'background2063.png', 'background2690.png', 'background4155.png', 'background2674.png', 'background1909.png', 'background2149.png', 'background2010.png', 'background3387.png', 'background2672.png', 'background2543.png', 'background2217.png', 'background1883.png', 'background62.png', 'background2531.png', 'background1227.png', 'background2919.png', 'background184.png', 'background312.png', 'background3156.png', 'background2642.png', 'background484.png', 'background48.png', 'background357.png', 'background3060.png', 'background2860.png', 'background1652.png', 'background504.png', 'background138.png', 'background1988.png', 'background3216.png', 'background1826.png', 'background3148.png', 'background2032.png', 'background2071.png', 'background4031.png', 'background2946.png', 'background3710.png', 'background2987.png', 'background2307.png', 'background777.png', 'background2157.png', 'background288.png', 'background1666.png', 'background1574.png', 'background3206.png', 'background2256.png', 'background674.png', 'background3515.png', 'background1353.png', 'background862.png', 'background2720.png', 'background1977.png', 'background521.png', 'background2356.png', 'background2351.png', 'background2162.png', 'background3309.png', 'background4081.png', 'background2474.png', 'background148.png', 'background11.png', 'background1915.png', 'background3316.png', 'background3157.png', 'background1086.png', 'background422.png', 'background3569.png', 'background1763.png', 'background614.png' ...
