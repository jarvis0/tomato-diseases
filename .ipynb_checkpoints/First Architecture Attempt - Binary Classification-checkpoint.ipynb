# %%
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
import os
import random
import shutil
import torchvision.datasets as datasets
import torchvision

# %%
GPU_MODE = True

# %%
classes = ['healthy', 'Bacterial_spot', 'Early_blight', 'Late_blight', 'Leaf_Mold', 'Septoria_leaf_spot', 
           'Spider_mites Two-spotted_spider_mite', 'Target_Spot', 'Tomato_mosaic_virus', 
          'Tomato_Yellow_Leaf_Curl_Virus']
binary_classes = ['healthy', 'non_healthy']
if os.path.exists('data/'):
    shutil.rmtree('data/')
os.mkdir('data/')
os.mkdir('data/test')
os.mkdir('data/test/healthy')
os.mkdir('data/test/non_healthy')
for cls in classes:
    if cls == 'healthy':
        shutil.copytree("original_dataset/" + cls , "data/train/healthy/")
        files = os.listdir('data/train/healthy') # dir is your directory path
        number_files = len(files)
        for i in range(int(number_files * 0.2)): #testing parameter
            src = random.choice(os.listdir("data/train/healthy/"))
            shutil.move("data/train/healthy/" + src, "data/test/healthy/" + src)
        os.mkdir('data/train/non_healthy')
    else:
        for i in range(133):
            src = random.choice(os.listdir("original_dataset/" + cls))
            shutil.copyfile("original_dataset/" + cls + '/' + src, "data/train/non_healthy/" + src)
        for i in range(33):
            src = random.choice(os.listdir("data/train/non_healthy/"))
            shutil.move("data/train/non_healthy/" + src, "data/test/non_healthy/" + src)

# %%
data_dir = 'data/'
batch_size = 16
data_transforms = {
        'train': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]),
        'test': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])}

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                      data_transforms[x]) for x in ['train', 'test']}
trainloader = torch.utils.data.DataLoader(image_datasets['train'], batch_size=batch_size,
                                         shuffle=True, num_workers=4)
testloader = torch.utils.data.DataLoader(image_datasets['test'], batch_size=batch_size,
                                         shuffle=True, num_workers=4)

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image


def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % binary_classes[labels[j]] for j in range(batch_size)))
# Out:
# non_healthy healthy non_healthy healthy non_healthy healthy healthy healthy healthy non_healthy healthy healthy non_healthy healthy non_healthy healthy

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        # 1 input image channel,
        # 6 output channel,
        # 5x5 square convolution kernel
        self.conv1 = nn.Conv2d(3, 4, 5)
        self.conv2 = nn.Conv2d(4, 6, 5)
        self.conv3 = nn.Conv2d(6, 16, 5)
        # an affine operation
        self.fc1 = nn.Linear(16 * 28 * 28, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 2)
        
    def forward(self, x):
        # max pooling over a (2, 2) windows
        x = F.max_pool2d(F.relu(self.conv1(x)), 2)
        x = F.max_pool2d(F.relu(self.conv2(x)), 2)
        x = F.max_pool2d(F.relu(self.conv3(x)), 2)
        x = x.view(-1, self.num_flat_features(x))
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x
    
    def num_flat_features(self, x):
        size = x.size()[1:]
        num_features = 1
        for s in size:
            num_features *= s
        return num_features
    
model = Model()
print(model)
if(GPU_MODE):
    model = model.cuda()
# Out:
# Model(
#   (conv1): Conv2d (3, 4, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d (4, 6, kernel_size=(5, 5), stride=(1, 1))
#   (conv3): Conv2d (6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=12544, out_features=120)
#   (fc2): Linear(in_features=120, out_features=84)
#   (fc3): Linear(in_features=84, out_features=2)
# )

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# %%
num_epochs = 3
num_mini_batches = 32

for epoch in range(num_epochs):  # loop over the dataset multiple times

    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs
        inputs, labels = data

        # wrap them in Variable
        if GPU_MODE:
            inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
        else:
            inputs, labels = Variable(inputs), Variable(labels)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.data[0]
        if i % num_mini_batches == num_mini_batches - 1:
            print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss / num_mini_batches))
            running_loss = 0.0

print('Finished Training')
# Out:
# [1,    32] loss: 0.592
# [1,    64] loss: 0.556
# [1,    96] loss: 0.509
# [1,   128] loss: 0.400
# [2,    32] loss: 0.331
# [2,    64] loss: 0.320
# [2,    96] loss: 0.233
# [2,   128] loss: 0.266
# [3,    32] loss: 0.292
# [3,    64] loss: 0.241
# [3,    96] loss: 0.170
# [3,   128] loss: 0.206
# Finished Training

# %%
dataiter = iter(testloader)
images, labels = dataiter.next()

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % binary_classes[labels[j]] for j in range(16)))
# Out:
# GroundTruth:  non_healthy healthy healthy healthy healthy healthy non_healthy healthy non_healthy healthy healthy healthy healthy non_healthy non_healthy healthy

# %%
if GPU_MODE:
    outputs = model(Variable(images).cuda())
else:
    outputs = model(Variable(images))

# %%
_, predicted = torch.max(outputs.data, 1)

print('Predicted: ', ' '.join('%5s' % binary_classes[predicted.cpu()[j]]
                              for j in range(16)))
# Out:
# Predicted:  non_healthy healthy non_healthy healthy healthy healthy non_healthy non_healthy non_healthy healthy healthy healthy healthy non_healthy non_healthy healthy

# %%
correct = 0
total = 0
for data in testloader:
    images, labels = data
    if GPU_MODE:
        outputs = model(Variable(images).cuda())
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted.cpu() == labels).sum()
    else:
        outputs = model(Variable(images))
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum()

print('Accuracy of the network on the test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the test images: 89 %

# %%
class_correct = list(0. for i in range(2))
class_total = list(0. for i in range(2))
for data in testloader:
    images, labels = data
    if GPU_MODE:
        outputs = model(Variable(images).cuda())
        _, predicted = torch.max(outputs.data, 1)
        c = (predicted.cpu() == labels).squeeze()
    else:
        outputs = model(Variable(images))
        _, predicted = torch.max(outputs.data, 1)
        c = (predicted == labels).squeeze()
    for i in range(2):
        label = labels[i]
        class_correct[label] += c[i]
        class_total[label] += 1


for i in range(2):
    print('Accuracy of %5s : %2d %%' % (
        binary_classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of healthy : 79 %
# Accuracy of non_healthy : 97 %
